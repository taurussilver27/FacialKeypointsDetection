# %%
import keras
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from keras.layers import Dense, Activation,MaxPool1D, MaxPool2D, Conv1D, Conv2D, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D
from keras.models import Sequential, Model, model_from_json
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
from sklearn.utils import shuffle
from keras import applications
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
from sklearn.model_selection import train_test_split
import cv2
# %matplotlib inline

# %%
EXTRACT_FEATURES = False
FEATURE_FILE_NAME = "inception_features.npy"
np.random.seed(1)
from tensorflow import set_random_seed
set_random_seed(2)

# %%
def load(fname,test=False, cols=None):
    df = pd.read_csv(fname)
    
    df['Image'] = df['Image'].apply(lambda im: np.fromstring(im, sep=' '))
    
    if cols:
        df = df[list(cols)+['Image']]
    
    #print( df.count())
    df = df.dropna()
    columns = df.columns
    
    X = np.vstack(df['Image'].values)#/255
    X = X.astype(np.float32)
    
    if not test:
        y = df[df.columns[:-1]].values
        #y = (y-48)/48
        X, y = shuffle(X, y, random_state=20)
        y = y.astype(np.float32)
    else:
        y = None
        columns = None
    
    return X, y, columns

def load2d(fname,test=False, cols=None):
    
    X, y, columns = load(fname,test, cols)
    X = X.reshape(-1,96,96, 1)
    
    return X, y, columns

def array_to_img(x):
#     rgbimg = cv2.resize(cv2.cvtColor(x,cv2.COLOR_GRAY2RGB),(224,224))
    rgbimg = cv2.cvtColor(x,cv2.COLOR_GRAY2RGB)
    rgbimg = rgbimg[...,::-1].astype(np.float32)
    a = np.expand_dims(rgbimg, axis=0)
    a = preprocess_input(a)
    return a

# %%
X, y, columns = load2d("data/training.csv",test=False)
columns = np.array(list(columns[:-1]))
columns
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
inception_model = applications.inception_v3.InceptionV3(include_top=False, weights='imagenet', pooling='avg')

# %%
inception_features = []
inception_features_array = np.zeros([X_train.shape[0],2048])

if EXTRACT_FEATURES:
    for i in range(X_train.shape[0]):
        if(i%10 == 0):
            print('.',end='')
        img = array_to_img(X_train[i])
        features = inception_model.predict(img)
#         print(features.shape)
        inception_features_array[i] = features.flatten()
    file = open(FEATURE_FILE_NAME,"wb")
#     inception_features_array = np.array(inception_features)
    np.save(file,inception_features_array)
else:
    file = open(FEATURE_FILE_NAME,'rb')
    inception_features_array = np.load(file)

# %%
model = Sequential()

model.add(Conv1D(32,3,input_shape=(2048,1),strides=1))
model.add(Activation("relu"))
model.add(MaxPool1D(pool_size=2,strides=2))
model.add(Dropout(0.2))

model.add(Conv1D(64,2,strides=1))
model.add(Activation("relu"))
model.add(MaxPool1D(pool_size=2,strides=2))
model.add(Dropout(0.2))

model.add(Conv1D(128,2,strides=1))
model.add(Activation("relu"))
model.add(MaxPool1D(pool_size=2,strides=2))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(500))
model.add(Activation("relu"))

model.add(Dense(30))
model.add(Activation("relu"))

# %%
model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(),metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_63 (Conv1D)           (None, 2046, 32)          128
# _________________________________________________________________
# activation_351 (Activation)  (None, 2046, 32)          0
# _________________________________________________________________
# max_pooling1d_55 (MaxPooling (None, 1023, 32)          0
# _________________________________________________________________
# dropout_65 (Dropout)         (None, 1023, 32)          0
# _________________________________________________________________
# conv1d_64 (Conv1D)           (None, 1022, 64)          4160
# _________________________________________________________________
# activation_352 (Activation)  (None, 1022, 64)          0
# _________________________________________________________________
# max_pooling1d_56 (MaxPooling (None, 511, 64)           0
# _________________________________________________________________
# dropout_66 (Dropout)         (None, 511, 64)           0
# _________________________________________________________________
# conv1d_65 (Conv1D)           (None, 510, 128)          16512
# _________________________________________________________________
# activation_353 (Activation)  (None, 510, 128)          0
# _________________________________________________________________
# max_pooling1d_57 (MaxPooling (None, 255, 128)          0
# _________________________________________________________________
# dropout_67 (Dropout)         (None, 255, 128)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 32640)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 500)               16320500
# _________________________________________________________________
# activation_354 (Activation)  (None, 500)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 30)                15030
# _________________________________________________________________
# activation_355 (Activation)  (None, 30)                0
# =================================================================
# Total params: 16,356,330
# Trainable params: 16,356,330
# Non-trainable params: 0
# _________________________________________________________________

# %%
# save best weights
checkpointer = ModelCheckpoint(filepath='face_model_in1_cnn.h5', verbose=1, save_best_only=True)

# num epochs
epochs = 50


# X_train, X_test, y_train, y_test = train_test_split(inception_features_array, y, test_size=0.15, random_state=42)
# run model
inception_features_array = np.expand_dims(inception_features_array, axis=2)
hist = model.fit(inception_features_array,y_train,batch_size=1,epochs=epochs, 
                 validation_split=0.15, callbacks=[checkpointer], verbose=2)

# save model to json
model_json = model.to_json()
with open("face_model_in1_cnn.json", "w") as json_file:
    json_file.write(model_json)
# Out:
# Train on 1546 samples, validate on 273 samples
# Epoch 1/50
#  - 426s - loss: 7297.5801 - acc: 0.6940 - val_loss: 7307.5646 - val_acc: 0.7033
#
# Epoch 00001: val_loss improved from inf to 7307.56457, saving model to face_model_in1_cnn.h5
# Epoch 2/50
#  - 341s - loss: 6930.6436 - acc: 0.6675 - val_loss: 6124.5659 - val_acc: 0.7033
#
# Epoch 00002: val_loss improved from 7307.56457 to 6124.56587, saving model to face_model_in1_cnn.h5
# Epoch 3/50
#  - 340s - loss: 6114.7464 - acc: 0.6966 - val_loss: 6124.5063 - val_acc: 0.7033
#
# Epoch 00003: val_loss improved from 6124.56587 to 6124.50631, saving model to face_model_in1_cnn.h5
# Epoch 4/50
#  - 339s - loss: 6114.6385 - acc: 0.6973 - val_loss: 6124.2273 - val_acc: 0.7033
#
# Epoch 00004: val_loss improved from 6124.50631 to 6124.22725, saving model to face_model_in1_cnn.h5
# Epoch 5/50
#  - 331s - loss: 6114.5352 - acc: 0.7012 - val_loss: 6124.5221 - val_acc: 0.7033
#
# Epoch 00005: val_loss did not improve from 6124.22725
# Epoch 6/50
#  - 316s - loss: 6114.4464 - acc: 0.6902 - val_loss: 6124.3916 - val_acc: 0.7143
#
# Epoch 00006: val_loss did not improve from 6124.22725
# Epoch 7/50
#  - 314s - loss: 6114.3549 - acc: 0.7038 - val_loss: 6124.1715 - val_acc: 0.7070
#
# Epoch 00007: val_loss improved from 6124.22725 to 6124.17146, saving model to face_model_in1_cnn.h5
# Epoch 8/50
#  - 313s - loss: 6114.2648 - acc: 0.7018 - val_loss: 6124.1761 - val_acc: 0.7106
#
# Epoch 00008: val_loss did not improve from 6124.17146
# Epoch 9/50
#  - 313s - loss: 6114.1460 - acc: 0.7038 - val_loss: 6124.3392 - val_acc: 0.7033
#
# Epoch 00009: val_loss did not improve from 6124.17146
# Epoch 10/50
#  - 312s - loss: 6113.9998 - acc: 0.7083 - val_loss: 6124.2506 - val_acc: 0.7033
#
# Epoch 00010: val_loss did not improve from 6124.17146
# Epoch 11/50
#  - 312s - loss: 6113.8589 - acc: 0.7173 - val_loss: 6123.8985 - val_acc: 0.7179
#
# Epoch 00011: val_loss improved from 6124.17146 to 6123.89846, saving model to face_model_in1_cnn.h5
# Epoch 12/50
#  - 312s - loss: 6113.7106 - acc: 0.7167 - val_loss: 6123.8645 - val_acc: 0.7033
#
# Epoch 00012: val_loss improved from 6123.89846 to 6123.86447, saving model to face_model_in1_cnn.h5
# Epoch 13/50
#  - 312s - loss: 6113.5810 - acc: 0.7212 - val_loss: 6123.8710 - val_acc: 0.6777
#
# Epoch 00013: val_loss did not improve from 6123.86447
# Epoch 14/50
#  - 324s - loss: 6113.4438 - acc: 0.7329 - val_loss: 6123.8945 - val_acc: 0.7070
#
# Epoch 00014: val_loss did not improve from 6123.86447
# Epoch 15/50
#  - 328s - loss: 6113.3097 - acc: 0.7374 - val_loss: 6123.9893 - val_acc: 0.6630
#
# Epoch 00015: val_loss did not improve from 6123.86447
# Epoch 16/50
#  - 315s - loss: 6113.1728 - acc: 0.7626 - val_loss: 6123.8923 - val_acc: 0.7070
#
# Epoch 00016: val_loss did not improve from 6123.86447
# Epoch 17/50
#  - 313s - loss: 6113.0191 - acc: 0.7613 - val_loss: 6123.8248 - val_acc: 0.6923
#
# Epoch 00017: val_loss improved from 6123.86447 to 6123.82479, saving model to face_model_in1_cnn.h5
# Epoch 18/50
#  - 312s - loss: 6112.9253 - acc: 0.7723 - val_loss: 6123.8302 - val_acc: 0.6923
#
# Epoch 00018: val_loss did not improve from 6123.82479
# Epoch 19/50
#  - 311s - loss: 6112.8041 - acc: 0.7878 - val_loss: 6123.8368 - val_acc: 0.6850
#
# Epoch 00019: val_loss did not improve from 6123.82479
# Epoch 20/50
#  - 313s - loss: 5982.6136 - acc: 0.7736 - val_loss: 5954.4824 - val_acc: 0.6777
#
# Epoch 00020: val_loss improved from 6123.82479 to 5954.48242, saving model to face_model_in1_cnn.h5
# Epoch 21/50
#  - 314s - loss: 5944.3034 - acc: 0.8021 - val_loss: 5954.4655 - val_acc: 0.7143
#
# Epoch 00021: val_loss improved from 5954.48242 to 5954.46547, saving model to face_model_in1_cnn.h5
# Epoch 22/50
#  - 332s - loss: 5944.2073 - acc: 0.8014 - val_loss: 5954.2911 - val_acc: 0.6960
#
# Epoch 00022: val_loss improved from 5954.46547 to 5954.29115, saving model to face_model_in1_cnn.h5
# Epoch 23/50
#  - 349s - loss: 5944.1614 - acc: 0.8150 - val_loss: 5954.2362 - val_acc: 0.6447
#
# Epoch 00023: val_loss improved from 5954.29115 to 5954.23624, saving model to face_model_in1_cnn.h5
# Epoch 24/50
#  - 348s - loss: 5944.1087 - acc: 0.8208 - val_loss: 5954.3510 - val_acc: 0.6850
#
# Epoch 00024: val_loss did not improve from 5954.23624
# Epoch 25/50
#  - 362s - loss: 5944.0698 - acc: 0.8221 - val_loss: 5954.4284 - val_acc: 0.6850
#
# Epoch 00025: val_loss did not improve from 5954.23624
# Epoch 26/50
#  - 361s - loss: 5944.0330 - acc: 0.8215 - val_loss: 5954.2992 - val_acc: 0.6960
#
# Epoch 00026: val_loss did not improve from 5954.23624
# Epoch 27/50
#  - 362s - loss: 5943.9961 - acc: 0.8370 - val_loss: 5954.3790 - val_acc: 0.6740
#
# Epoch 00027: val_loss did not improve from 5954.23624
# Epoch 28/50
#  - 362s - loss: 5943.9702 - acc: 0.8454 - val_loss: 5954.2401 - val_acc: 0.6886
#
# Epoch 00028: val_loss did not improve from 5954.23624
# Epoch 29/50
#  - 361s - loss: 5943.9454 - acc: 0.8461 - val_loss: 5954.3688 - val_acc: 0.6557
#
# Epoch 00029: val_loss did not improve from 5954.23624
# Epoch 30/50
#  - 360s - loss: 5943.9170 - acc: 0.8486 - val_loss: 5954.2998 - val_acc: 0.6777
#
# Epoch 00030: val_loss did not improve from 5954.23624
# Epoch 31/50
#  - 356s - loss: 5943.8811 - acc: 0.8461 - val_loss: 5954.3219 - val_acc: 0.6886
#
# Epoch 00031: val_loss did not improve from 5954.23624
# Epoch 32/50
#  - 351s - loss: 5943.8832 - acc: 0.8525 - val_loss: 5954.2947 - val_acc: 0.6740
#
# Epoch 00032: val_loss did not improve from 5954.23624
# Epoch 33/50
#  - 360s - loss: 5943.8550 - acc: 0.8609 - val_loss: 5954.3023 - val_acc: 0.6996
#
# Epoch 00033: val_loss did not improve from 5954.23624
# Epoch 34/50
#  - 359s - loss: 5943.8491 - acc: 0.8512 - val_loss: 5954.3068 - val_acc: 0.6923
#
# Epoch 00034: val_loss did not improve from 5954.23624
# Epoch 35/50
#  - 359s - loss: 5943.8460 - acc: 0.8596 - val_loss: 5954.3483 - val_acc: 0.6593
#
# Epoch 00035: val_loss did not improve from 5954.23624
# Epoch 36/50
#  - 360s - loss: 5943.8117 - acc: 0.8532 - val_loss: 5954.2996 - val_acc: 0.6813
#
# Epoch 00036: val_loss did not improve from 5954.23624
# Epoch 37/50
#  - 362s - loss: 5943.7937 - acc: 0.8784 - val_loss: 5954.3012 - val_acc: 0.6813
#
# Epoch 00037: val_loss did not improve from 5954.23624
# Epoch 38/50
#  - 358s - loss: 5943.7956 - acc: 0.8642 - val_loss: 5954.2925 - val_acc: 0.7033
#
# Epoch 00038: val_loss did not improve from 5954.23624
# Epoch 39/50
#  - 361s - loss: 5943.7855 - acc: 0.8758 - val_loss: 5954.2591 - val_acc: 0.7033
#
# Epoch 00039: val_loss did not improve from 5954.23624
# Epoch 40/50
#  - 384s - loss: 5943.7752 - acc: 0.8823 - val_loss: 5954.2682 - val_acc: 0.7179
#
# Epoch 00040: val_loss did not improve from 5954.23624
# Epoch 41/50
#  - 489s - loss: 5943.7677 - acc: 0.8771 - val_loss: 5954.2150 - val_acc: 0.7106
#
# Epoch 00041: val_loss improved from 5954.23624 to 5954.21498, saving model to face_model_in1_cnn.h5
# Epoch 42/50
#  - 323s - loss: 5943.7550 - acc: 0.8687 - val_loss: 5954.2521 - val_acc: 0.6703
#
# Epoch 00042: val_loss did not improve from 5954.21498
# Epoch 43/50
#  - 312s - loss: 5943.7511 - acc: 0.8816 - val_loss: 5954.2431 - val_acc: 0.6777
#
# Epoch 00043: val_loss did not improve from 5954.21498
# Epoch 44/50
#  - 313s - loss: 5943.7429 - acc: 0.8745 - val_loss: 5954.2184 - val_acc: 0.7106
#
# Epoch 00044: val_loss did not improve from 5954.21498
# Epoch 45/50
#  - 311s - loss: 5943.7339 - acc: 0.8758 - val_loss: 5954.2026 - val_acc: 0.6923
#
# Epoch 00045: val_loss improved from 5954.21498 to 5954.20257, saving model to face_model_in1_cnn.h5
# Epoch 46/50
#  - 331s - loss: 5943.7316 - acc: 0.8862 - val_loss: 5954.1762 - val_acc: 0.6703
#
# Epoch 00046: val_loss improved from 5954.20257 to 5954.17616, saving model to face_model_in1_cnn.h5
# Epoch 47/50
#  - 339s - loss: 5943.7239 - acc: 0.8765 - val_loss: 5954.2282 - val_acc: 0.6923
#
# Epoch 00047: val_loss did not improve from 5954.17616
# Epoch 48/50
#  - 315s - loss: 5943.7161 - acc: 0.8758 - val_loss: 5954.1990 - val_acc: 0.6850
#
# Epoch 00048: val_loss did not improve from 5954.17616
# Epoch 49/50
#  - 349s - loss: 5943.7096 - acc: 0.8784 - val_loss: 5954.1694 - val_acc: 0.7070
#
# Epoch 00049: val_loss improved from 5954.17616 to 5954.16940, saving model to face_model_in1_cnn.h5
# Epoch 50/50
#  - 335s - loss: 5943.7047 - acc: 0.8926 - val_loss: 5954.2331 - val_acc: 0.6777
#
# Epoch 00050: val_loss did not improve from 5954.16940
